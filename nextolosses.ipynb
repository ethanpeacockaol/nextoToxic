# %% [markdown]
# # Nexto Toxic Losses

# %%
losses = []
losses.append(21)

# %%
losses.append(26)

# %%
losses.append(22)

# %%
losses.append(12)

# %%
losses.append(18)

# %%
import matplotlib.pyplot as plt

# %%
plt.title('Nexto Loss Stats')
plt.plot([i for i in range(len(losses))], losses, 'r.', label="losses")
plt.plot([i for i in range(len(losses))], losses, 'r')
plt.ylabel('nexttoToxic final score')
plt.legend()
plt.show()
